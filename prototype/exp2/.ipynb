# %%
import json
import matplotlib.pyplot as plt

# %%
L = json.load(open("/app/prototype/exp2/output/sharpe_ratio_history.json"))
plt.plot(L)
plt.show()

# %%
L = json.load(open("/app/prototype/exp2/output/history.json"))
plt.plot(L["train_loss_list"])
plt.plot(L["valid_loss_list"])
plt.show()
